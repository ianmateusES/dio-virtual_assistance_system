# %% [markdown]
# <a href="https://colab.research.google.com/github/ianmateusES/dio-virtual_assistance_system/blob/main/virtual_assistance_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sistema de assistente virtual

# %%
# !pip install gTTS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
from datetime import datetime

# %% [markdown]
# ## Text-to-Speech

# %%
import librosa
import soundfile as sf
from gtts import gTTS
from IPython.display import Audio

# %%
# Criando o diretorio que vai conter os audios
path = '/content/Speech'
if not os.path.exists(path):
    os.mkdir(path)

# %%
text = 'Que dia é hoje?'
lang = 'pt'

speech = gTTS(text=text, lang=lang, slow=True)
name_speech = f'{datetime.now().timestamp()}.wav'

speech.save(f'./Speech/{name_speech}')

x,_ = librosa.load(f'/content/Speech/{name_speech}', sr=16000)
sf.write(f'/content/Speech/{name_speech}', x, 16000)

del x, speech

# %%
Audio(f'/content/Speech/{name_speech}')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Speech-to-Text

# %%
# !pip install SpeechRecognition
# !pip install pydub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 33.8 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import webbrowser
import speech_recognition as sr
from pydub import AudioSegment

# %%
files = [i for i in os.listdir('/content/Speech') if i != '.ipynb_checkpoints']
files.sort(reverse=True)
files
# Out:
# ['1685035888.649428.wav']

# %%
lang = 'pt'
name_speech = files[0]

r = sr.Recognizer()

with sr.AudioFile(f'/content/Speech/{name_speech}') as source:
    audio = r.record(source)  # Lê o áudio do arquivo

try:
    transcript = r.recognize_google(audio, language=lang)
    print("Transcrição: " + transcript)
    url = f"https://www.google.com/search?q={transcript}"
    webbrowser.open(url)
except sr.UnknownValueError:
    print("Não foi possível reconhecer o áudio.")
except sr.RequestError:
    print("Erro na solicitação ao serviço de reconhecimento de fala.")
# Out:
# Transcrição: Que dia é hoje
